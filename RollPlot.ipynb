# %% [markdown]
# <a href="https://colab.research.google.com/github/Iammufarooq/Iammufarooq/blob/main/RollPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Importing the dataset
data = pd.read_excel('/content/DOE_Surf.xlsx')

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

thickness = data['Thickness1100']
width = data['Width1100']
force = data['Theo1100']
force2 = data['Engg1100']
points = np.array([thickness, width]).T

xi = np.linspace(min(thickness), max(thickness), 100)
yi = np.linspace(min(width), max(width), 100)

xi, yi = np.meshgrid(xi, yi)

zi = griddata(points, force, (xi, yi), method='cubic')


ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)

zi = griddata(points, force2, (xi, yi), method='cubic')

ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

zi = griddata(points, force, (xi, yi), method='cubic')
surf1 = ax.plot_surface(xi, yi, zi, color='blue', alpha=0.5, label='Force')

zi = griddata(points, force2, (xi, yi), method='cubic')
surf2 = ax.plot_surface(xi, yi, zi, color='red', alpha=0.5, label='Force2')

ax.set_xlabel('Thickness (mm)')
ax.set_ylabel('Width (mm)')
ax.set_zlabel('Rolling Power (W)')

# I'll create proxy artists for the legend because legend does not work with 3D objects by default
import matplotlib.lines as mlines
blue_line = mlines.Line2D([], [], color='blue', label='Source (Physics model)')
red_line = mlines.Line2D([], [], color='red', label='Target (Experiments)')

# You can adjust positioning as necessary
ax.legend(handles=[blue_line, red_line], loc='upper right')

plt.show()

# %%
thickness = data['Thickness1100']
width = data['Reduction1100']
force = data['Theo1100']
force2 = data['Engg1100']
points = np.array([thickness, width]).T

xi = np.linspace(min(thickness), max(thickness), 100)
yi = np.linspace(min(width), max(width), 100)

xi, yi = np.meshgrid(xi, yi)

zi = griddata(points, force, (xi, yi), method='cubic')


ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)

zi = griddata(points, force2, (xi, yi), method='cubic')

ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

zi = griddata(points, force, (xi, yi), method='cubic')
surf1 = ax.plot_surface(xi, yi, zi, color='blue', alpha=0.5, label='Force')

zi = griddata(points, force2, (xi, yi), method='cubic')
surf2 = ax.plot_surface(xi, yi, zi, color='red', alpha=0.5, label='Force2')

ax.set_xlabel('Thickness (mm)')
ax.set_ylabel('Reduction (%)')
ax.set_zlabel('Rolling Power (W)')

# I'll create proxy artists for the legend because legend does not work with 3D objects by default
import matplotlib.lines as mlines
blue_line = mlines.Line2D([], [], color='blue', label='Source (Physics model)')
red_line = mlines.Line2D([], [], color='red', label='Target (Experiments)')

# You can adjust positioning as necessary
ax.legend(handles=[blue_line, red_line], loc='upper right')

plt.show()

# %%
thickness = data['Width1100']
width = data['Reduction1100']
force = data['Theo1100']
force2 = data['Engg1100']
points = np.array([thickness, width]).T

xi = np.linspace(min(thickness), max(thickness), 100)
yi = np.linspace(min(width), max(width), 100)

xi, yi = np.meshgrid(xi, yi)

zi = griddata(points, force, (xi, yi), method='cubic')


ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)

zi = griddata(points, force2, (xi, yi), method='cubic')

ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

zi = griddata(points, force, (xi, yi), method='cubic')
surf1 = ax.plot_surface(xi, yi, zi, color='blue', alpha=0.5, label='Force')

zi = griddata(points, force2, (xi, yi), method='cubic')
surf2 = ax.plot_surface(xi, yi, zi, color='red', alpha=0.5, label='Force2')

ax.set_xlabel('Width (mm)')
ax.set_ylabel('Reduction (%)')
ax.set_zlabel('Rolling Power (W)')

# I'll create proxy artists for the legend because legend does not work with 3D objects by default
import matplotlib.lines as mlines
blue_line = mlines.Line2D([], [], color='blue', label='Source (Physics model)')
red_line = mlines.Line2D([], [], color='red', label='Target (Experiments)')
# You can adjust positioning as necessary
ax.legend(handles=[blue_line, red_line], loc='upper right')

plt.show()

# %%
thickness = data['Thickness6061'].dropna()
width = data['Width6061'].dropna()
force = data['Theo6061'].dropna()
force2 = data['Engg6061'].dropna()
points = np.array([thickness, width]).T

xi = np.linspace(min(thickness), max(thickness), 100)
yi = np.linspace(min(width), max(width), 100)

xi, yi = np.meshgrid(xi, yi)
points
zi = griddata(points, force, (xi, yi), method='cubic')


ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)

zi = griddata(points, force2, (xi, yi), method='cubic')

ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

zi = griddata(points, force, (xi, yi), method='cubic')
surf1 = ax.plot_surface(xi, yi, zi, color='blue', alpha=0.5, label='Force')

zi = griddata(points, force2, (xi, yi), method='cubic')
surf2 = ax.plot_surface(xi, yi, zi, color='red', alpha=0.5, label='Force2')

ax.set_xlabel('Thickness (mm)')
ax.set_ylabel('Width (mm)')
ax.set_zlabel('Rolling Power (W)')

# I'll create proxy artists for the legend because legend does not work with 3D objects by default
import matplotlib.lines as mlines
blue_line = mlines.Line2D([], [], color='blue', label='Source (Physics model)')
red_line = mlines.Line2D([], [], color='red', label='Target (Experiments)')

# You can adjust positioning as necessary
ax.legend(handles=[blue_line, red_line], loc='upper right')

plt.show()

# %%
thickness = data['Thickness6061'].dropna()
width = data['Reduction6061'].dropna()
force = data['Theo6061'].dropna()
force2 = data['Engg6061'].dropna()
points = np.array([thickness, width]).T

xi = np.linspace(min(thickness), max(thickness), 100)
yi = np.linspace(min(width), max(width), 100)

xi, yi = np.meshgrid(xi, yi)

zi = griddata(points, force, (xi, yi), method='cubic')


ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)

zi = griddata(points, force2, (xi, yi), method='cubic')

ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

zi = griddata(points, force, (xi, yi), method='cubic')
surf1 = ax.plot_surface(xi, yi, zi, color='blue', alpha=0.5, label='Force')

zi = griddata(points, force2, (xi, yi), method='cubic')
surf2 = ax.plot_surface(xi, yi, zi, color='red', alpha=0.5, label='Force2')

ax.set_xlabel('Thickness (mm)')
ax.set_ylabel('Reduction (%)')
ax.set_zlabel('Rolling Power (W)')

# I'll create proxy artists for the legend because legend does not work with 3D objects by default
import matplotlib.lines as mlines
blue_line = mlines.Line2D([], [], color='blue', label='Source (Physics model)')
red_line = mlines.Line2D([], [], color='red', label='Target (Experiments)')

# You can adjust positioning as necessary
ax.legend(handles=[blue_line, red_line], loc='upper right')

plt.show()

# %%
thickness = data['Width6061'].dropna()
width = data['Reduction6061'].dropna()
force = data['Theo6061'].dropna()
force2 = data['Engg6061'].dropna()
points = np.array([thickness, width]).T

xi = np.linspace(min(thickness), max(thickness), 100)
yi = np.linspace(min(width), max(width), 100)

xi, yi = np.meshgrid(xi, yi)

zi = griddata(points, force, (xi, yi), method='cubic')


ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)

zi = griddata(points, force2, (xi, yi), method='cubic')

ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xi, yi, zi, cmap='viridis', linewidth=0.2)

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

zi = griddata(points, force, (xi, yi), method='cubic')
surf1 = ax.plot_surface(xi, yi, zi, color='blue', alpha=0.5, label='Force')

zi = griddata(points, force2, (xi, yi), method='cubic')
surf2 = ax.plot_surface(xi, yi, zi, color='red', alpha=0.5, label='Force2')

ax.set_xlabel('Width (mm)')
ax.set_ylabel('Reduction (%)')
ax.set_zlabel('Rolling Power (W)')

# I'll create proxy artists for the legend because legend does not work with 3D objects by default
import matplotlib.lines as mlines
blue_line = mlines.Line2D([], [], color='blue', label='Source (Physics model)')
red_line = mlines.Line2D([], [], color='red', label='Target (Experiments)')

# You can adjust positioning as necessary
ax.legend(handles=[blue_line, red_line], loc='upper right')

plt.show()

# %%
from matplotlib import pyplot as plt
thickness = data['Width6061'].dropna()
width = data['Reduction6061'].dropna()
force = data['Theo6061'].dropna()
force2 = data['Engg6061'].dropna()

# %%
plt.plot(thickness, force, 'bo')
plt.plot(thickness, force2, 'go')
